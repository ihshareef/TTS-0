# %% [markdown]
# <a href="https://colab.research.google.com/github/ihshareef/TTS-0/blob/master/tacotron_training_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Git repo cloning

# %%
# !git clone https://github.com/coqui-ai/TTS TTS_repo
# %cd TTS_repo
# !git checkout e9e0784
# !pip install -r requirements.txt
# !python setup.py develop
# %cd ..
# Out:
# Cloning into 'TTS_repo'...
# remote: Enumerating objects: 28145, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 28145 (delta 48), reused 56 (delta 31), pack-reused 28052
# Receiving objects: 100% (28145/28145), 129.32 MiB | 24.24 MiB/s, done.
# Resolving deltas: 100% (20512/20512), done.
# /content/TTS_repo
# Note: checking out 'e9e0784'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at e9e07844 Update README.md
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Install files

# %%
# !wget https://www.dropbox.com/s/iyrr2il4bmq75bl/dataset_coqui.zip
# !sudo apt install unzip
# !unzip dataset_coqui.zip -d dataset
# !rm -rf dataset_coqui.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08kyz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08l0z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08oxz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08p0z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08qez.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08rez.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08vmz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08wmz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08xyz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k08y0z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d09z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d2ez.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d59z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d69z.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d7mz.wav
#   inflating: dataset/wavs/khadeejafaaz_6_p3k0d80z.wav
# ...

# %%
# create train-val splits
# !shuf /content/dataset/metadata.csv > /content/dataset/metadata_shuf.csv
# !head -n 10635 /content/dataset/metadata_shuf.csv > /content/dataset/metadata_train.csv
# !tail -n 1000 /content/dataset/metadata_shuf.csv > /content/dataset/metadata_val.csv

# %%
# %cd /content/dataset
# !wc -l ./metadata.csv
# %cd ..
# Out:
# /content/dataset
# 11635 ./metadata.csv
# /content

# %%
# !wget https://www.dropbox.com/s/42x7utc6h3vwvhi/config.json
# !wget https://www.dropbox.com/s/9a0uhomdpkek83z/scale_stats.npy
# !wget https://www.dropbox.com/s/3bsm7d2lwdk56hi/sentences.txt
# Out:
# --2022-11-15 04:27:22--  https://www.dropbox.com/s/42x7utc6h3vwvhi/config.json
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/42x7utc6h3vwvhi/config.json [following]
# --2022-11-15 04:27:22--  https://www.dropbox.com/s/raw/42x7utc6h3vwvhi/config.json
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8e42616b400deffbc97750e57a.dl.dropboxusercontent.com/cd/0/inline/BwxsgJ0ykN8fyjPSWsBAgvaxvb4q8tftC5tHhZ-TSEclLcA16nY2PL23ClaqrPKEdzYklnJHWDqA4A_2rKtNPu6PXAFndu3acIJJVibeV8k9_UlgF3BYsp1npOrb876vOt_oMvBi6BJaIx2tMAHLWhG0Uh_bdwsyUOcaQ_WQFrKFSg/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/6llq2m83a0zpmfb/best_model.pth.tar

# %%
# !pip uninstall torch torchvision 
# !pip install torch==1.6.0 torchvision==0.7.0
# Out:
# Found existing installation: torch 1.12.1+cu113
# Uninstalling torch-1.12.1+cu113:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.7/dist-packages/caffe2/*
#     /usr/local/lib/python3.7/dist-packages/torch-1.12.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torch/*
#     /usr/local/lib/python3.7/dist-packages/torchgen/*
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.12.1+cu113
# Found existing installation: torchvision 0.13.1+cu113
# Uninstalling torchvision-0.13.1+cu113:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/torchvision-0.13.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libcudart.053364c0.so.11.0
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libjpeg.ceea7512.so.62
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libnvjpeg.90286a3c.so.11
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# train 
# !CUDA_DEVICES_AVAILABLE="0" python /content/TTS_repo/TTS/bin/train_tacotron.py --config_path /content/config.json
# Out:
# Streaming output truncated to the last 5000 lines.
#      | > stopnet_loss: 0.22435  (0.24770)
#      | > decoder_coarse_loss: 0.24302  (0.24187)
#      | > decoder_ddc_loss: 0.01544  (0.01668)
#      | > ga_loss: 0.00430  (0.00485)
#      | > decoder_diff_spec_loss: 0.11243  (0.11110)
#      | > postnet_diff_spec_loss: 0.11335  (0.11611)
#      | > decoder_ssim_loss: 0.30448  (0.30633)
#      | > postnet_ssim_loss: 0.29951  (0.30524)
#      | > loss: 0.50169  (0.50955)
#      | > align_error: 0.35017  (0.33447)
#      | > max_spec_length: 225.0
#      | > max_text_length: 13.0
#      | > step_time: 0.6070
#      | > loader_time: 0.00
#      | > current_lr: 0.0001
#
#    --> STEP: 74/324 -- GLOBAL_STEP: 12100
#      | > decoder_loss: 0.21965  (0.19848)
#      | > postnet_loss: 0.20297  (0.18767)
#      | > stopnet_loss: 0.20063  (0.23592)
#      | > decoder_coarse_loss: 0.24864  (0.24228)
#      | > decoder_ddc_loss: 0.01531  (0.01596)
#      | > ga_loss: 0.00245  (0.00431)
# ...

# %%
# train 
# !CUDA_DEVICES_AVAILABLE="0" python /content/TTS_repo/TTS/bin/train_tacotron.py --continue_path /content/drive/MyDrive/javaabu_voice/kf-javaabu-scratch-ddc-2-November-03-2022_07+24AM-0000000
# Out:
# Streaming output truncated to the last 5000 lines.
#      | > stopnet_loss: 0.07661  (0.14511)
#      | > decoder_coarse_loss: 0.15305  (0.12516)
#      | > decoder_ddc_loss: 0.00581  (0.01226)
#      | > ga_loss: 0.00023  (0.00217)
#      | > decoder_diff_spec_loss: 0.09187  (0.08064)
#      | > postnet_diff_spec_loss: 0.08437  (0.07500)
#      | > decoder_ssim_loss: 0.24825  (0.21772)
#      | > postnet_ssim_loss: 0.21919  (0.19596)
#      | > loss: 0.31540  (0.28595)
#      | > align_error: 0.30517  (0.29455)
#      | > max_spec_length: 526.0
#      | > max_text_length: 72.0
#      | > step_time: 1.1136
#      | > loader_time: 0.00
#      | > current_lr: 0.0001
#
#    --> STEP: 324/649 -- GLOBAL_STEP: 107625
#      | > decoder_loss: 0.11089  (0.09030)
#      | > postnet_loss: 0.09472  (0.07952)
#      | > stopnet_loss: 0.03317  (0.13810)
#      | > decoder_coarse_loss: 0.16417  (0.12770)
#      | > decoder_ddc_loss: 0.00221  (0.01166)
#      | > ga_loss: 0.00008  (0.00201)
# ...
